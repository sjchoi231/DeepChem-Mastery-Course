# %% [markdown]
# #**1.3 An Introduction To MoleculeNet**

# %%
# !pip install --pre deepchem

# %%
import deepchem as dc
dc.__version__

# %%
tasks ,  datasets ,  transformers  =  dc.molnet.load_delaney ( featurizer = 'graphconv' , splitter = 'random' )

# %% [markdown]
# delaney 데이터셋 중 그래프 구조로 변환해서 random split

# %%
[method for method in dir(dc.molnet) if "load_" in method ]
# Out:
# ['load_Platinum_Adsorption',
#  'load_bace_classification',
#  'load_bace_regression',
#  'load_bandgap',
#  'load_bbbc001',
#  'load_bbbc002',
#  'load_bbbc003',
#  'load_bbbc004',
#  'load_bbbc005',
#  'load_bbbp',
#  'load_cell_counting',
#  'load_chembl',
#  'load_chembl25',
#  'load_clearance',
#  'load_clintox',
#  'load_delaney',
#  'load_factors',
#  'load_freesolv',
#  'load_function',
#  'load_hiv',
#  'load_hopv',
#  'load_hppb',
#  'load_kaggle',
#  'load_kinase',
#  'load_lipo',
#  'load_mp_formation_energy',
#  'load_mp_metallicity',
#  'load_muv',
#  'load_nci',
#  'load_pcba',
#  'load_pdbbind',
#  'load_perovskite',
#  'load_ppb',
#  'load_qm7',
#  'load_qm8',
#  'load_qm9',
#  'load_sampl',
#  'load_sider',
#  'load_sweet',
#  'load_thermosol',
#  'load_tox21',
#  'load_toxcast',
#  'load_uspto',
#  'load_uv',
#  'load_zinc15']

# %% [markdown]
# dc.molnet 안 load로 시작하는 다른 데이터셋들 확인

# %%
len([method for method in dir(dc.molnet) if "load_" in method ])
# Out:
# 45

# %%
tasks
# Out:
# ['measured log solubility in mols per litre']

# %%
datasets
# Out:
# (<DiskDataset X.shape: (902,), y.shape: (902, 1), w.shape: (902, 1), ids: ['Nc2cnn(c1ccccc1)c(=O)c2Cl' 'CCCCCBr' 'CCc1cccc2ccccc12' ... 'CCOC=O'
#   'Clc1ccc(Cl)c(c1)c2cccc(Cl)c2Cl ' 'CC(C)C(O)C(C)C'], task_names: ['measured log solubility in mols per litre']>,
#  <DiskDataset X.shape: (113,), y.shape: (113, 1), w.shape: (113, 1), ids: ['CC1=CC(=O)CC(C)(C)C1 ' 'CCCCCC=C' 'CCCCCCl' ... 'Cc1cc2ccccc2cc1C'
#   'O=c1[nH]cnc2[nH]ncc12 ' 'O=C2NC(=O)C1(CC1)C(=O)N2 '], task_names: ['measured log solubility in mols per litre']>,
#  <DiskDataset X.shape: (113,), y.shape: (113, 1), w.shape: (113, 1), ids: ['Cc1cc2c3ccccc3ccc2c4ccccc14' 'CC34CCC1C(CCC2CC(O)CCC12C)C3CCC4=O'
#   'C(c1ccccc1)c2ccccc2' ... 'CCC(=O)OC3CCC4C2CCC1=CC(=O)CCC1(C)C2CCC34C '
#   'CCCCC(=O)C' 'Cc1cc(C)c(C)c(C)c1C'], task_names: ['measured log solubility in mols per litre']>)

# %%
train, valid, test = datasets

# %%
train
# Out:
# <DiskDataset X.shape: (902,), y.shape: (902, 1), w.shape: (902, 1), ids: ['Nc2cnn(c1ccccc1)c(=O)c2Cl' 'CCCCCBr' 'CCc1cccc2ccccc12' ... 'CCOC=O'
#  'Clc1ccc(Cl)c(c1)c2cccc(Cl)c2Cl ' 'CC(C)C(O)C(C)C'], task_names: ['measured log solubility in mols per litre']>

# %%
valid
# Out:
# <DiskDataset X.shape: (113,), y.shape: (113, 1), w.shape: (113, 1), ids: ['CC1=CC(=O)CC(C)(C)C1 ' 'CCCCCC=C' 'CCCCCCl' ... 'Cc1cc2ccccc2cc1C'
#  'O=c1[nH]cnc2[nH]ncc12 ' 'O=C2NC(=O)C1(CC1)C(=O)N2 '], task_names: ['measured log solubility in mols per litre']>

# %%
test
# Out:
# <DiskDataset X.shape: (113,), y.shape: (113, 1), w.shape: (113, 1), ids: ['Cc1cc2c3ccccc3ccc2c4ccccc14' 'CC34CCC1C(CCC2CC(O)CCC12C)C3CCC4=O'
#  'C(c1ccccc1)c2ccccc2' ... 'CCC(=O)OC3CCC4C2CCC1=CC(=O)CCC1(C)C2CCC34C '
#  'CCCCC(=O)C' 'Cc1cc(C)c(C)c(C)c1C'], task_names: ['measured log solubility in mols per litre']>

# %%
train.X[0]

# %%
transformers

# %%
tasks, datasets, transformers = dc.molnet.load_delaney(featurizer="ECFP", splitter="scaffold")

# %%
(train, valid, test) = datasets

# %%
train
# Out:
# <DiskDataset X.shape: (902, 1024), y.shape: (902, 1), w.shape: (902, 1), ids: ['CC(C)=CCCC(C)=CC(=O)' 'CCCC=C' 'CCCCCCCCCCCCCC' ...
#  'Nc2cccc3nc1ccccc1cc23 ' 'C1CCCCCC1' 'OC1CCCCCC1'], task_names: ['measured log solubility in mols per litre']>

# %%
train.X[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ## 💡 Insight & Reflection
# DeepChem의 load_delaney 로더를 통해 데이터 로딩부터 분할(Split)까지 한 줄로 끝내는 파이프라인을 경험함. 데이터 전처리 시간을 줄이고 모델 아키텍처 설계에 더 집중할 수 있는 환경을 구축함
